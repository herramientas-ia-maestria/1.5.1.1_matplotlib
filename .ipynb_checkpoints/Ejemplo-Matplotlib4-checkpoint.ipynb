# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

# %%
df = pd.read_csv("data/defunciones.csv")

# %%
df
# Out:
#        Unnamed: 0  folio  ofi_insc    prov_insc  \
# 0               1    NaN         1       Azuay
# 1               2    NaN         1       Azuay
# 2               3    NaN         1       Azuay
# 3               4    NaN         1       Azuay
# 4               5    NaN         1       Azuay
# ...           ...    ...       ...          ...
# 63099       63100    NaN         1  Esmeraldas
# 63100       63101    NaN         1      Zamora
# 63101       63102    NaN         1  Esmeraldas
# 63102       63103    NaN         1   Sucumbios
# 63103       63104    NaN         1      Manabi
#
#                                                cant_insc  \
# 0      Cuenca                                        ...
# 1      Cuenca                                        ...
# 2      Cuenca                                        ...
# 3      Cuenca                                        ...
# 4      Cuenca                                        ...
# ...

# %%
print(df.shape)
# Out:
# (63104, 53)

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'folio', 'ofi_insc', 'prov_insc', 'cant_insc',
#        'parr_insc', 'anio_insc', 'mes_insc', 'dia_insc', 'fecha_insc',
#        'acta_insc', 'sexo', 'anio_nac', 'mes_nac', 'dia_nac', 'fecha_nac',
#        'anio_fall', 'mes_fall', 'dia_fall', 'fecha_fall', 'nac_fall',
#        'cod_pais', 'edad', 'cod_edad', 'prov_res', 'cant_res', 'parr_res',
#        'loc_res', 'area_res', 'est_civil', 'sabe_leer', 'niv_inst', 'etnia',
#        'lugar_ocur', 'cod_esta', 'prov_fall', 'cant_fall', 'parr_fall',
#        'loc_fall', 'area_fall', 'causa4', 'mor_mat', 'mor_viol', 'lug_viol',
#        'autopsia', 'cer_por', 'parent_fall', 'causa', 'causa103', 'causa80',
#        'causa67A', 'causa67B', 'lc1'],
#       dtype='object')

# %%
print(df.causa103.unique())
# Out:
# ['054 Resto de enferm.endocrinas, nutricionales y metabólicas '
#  '046 Resto de tumores malignos                               '
#  '076 Enfermedades crónicas de las vías resp inferiores       '
#  '040 Tumor maligno de la próstata                            '
#  '074 Neumonia                                                '
#  '093 Malformac congénitas  deformidades y anomal cromosom    '
#  '047 Resto de tumores                                        '
#  '081 Resto de enfermedades del sistema digestivo             '
#  '052 Diabetes mellitus                                       '
#  '080 Enfermedades del hígado                                 '
#  '103 Todas las demás causas externas                         '
#  '069 Enfermedades Cerebro vasculares                          '
#  '070 Aterosclerosis                                          '
#  '092 Ciertas afecciones originadas en el periodo perinatal   '
#  '086 Resto de enfermedades del sistema genitourinario        '
# ...

# %%
df.causa103.value_counts()[:20].sort_values(inplace=False).plot(kind='barh');
# https://stackoverflow.com/questions/44123874/dataframe-object-has-no-attribute-sort

# %%
df[df['prov_insc'].str.strip()=='Pichincha'].causa103.value_counts()[:15].sort_values(inplace=False).plot(kind='barh');
